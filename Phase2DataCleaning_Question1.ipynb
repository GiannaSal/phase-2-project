# %% [markdown]
# Phase2Group Project
# "WHICH GENRE CONSIDSTENTLY EARNS THE MOST?"
# What "consistently" may mean (e.g., median revenue, top-quartile frequency or multi-year stability)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Setting up and locating the data.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import sqlite3
import zipfile
import gzip
import os
import re
import ast

pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 200)

ROOT = Path(".").resolve()
DATA_DIR = ROOT / "zippedData"

ROOT, DATA_DIR, DATA_DIR.exists()
# Out:
# (PosixPath('/Users/kilonzicharityvivi/Desktop/phase_2_project'),
#  PosixPath('/Users/kilonzicharityvivi/Desktop/phase_2_project/zippedData'),
#  False)

# %%
from pathlib import Path
ROOT = Path(".").resolve()
ROOT
# Out:
# PosixPath('/Users/kilonzicharityvivi/Desktop/phase_2_project')

# %%
sorted([p.name for p in ROOT.iterdir() if p.is_dir()])
# Out:
# ['.ipynb_checkpoints', '.jupyter']

# %%
matches = list(ROOT.rglob("zippedData"))
matches
# Out:
# []

# %%
candidates = [p for p in ROOT.rglob("*") if p.is_dir() and p.name.lower() in {"zippeddata", "data", "datasets", "raw", "input"}]
candidates[:20]
# Out:
# []

# %%
DATA_DIR = ROOT / "zippedData"   # change "zippedData" to the correct folder name you found
DATA_DIR.exists(), DATA_DIR
# Out:
# (False,
#  PosixPath('/Users/kilonzicharityvivi/Desktop/phase_2_project/zippedData'))
